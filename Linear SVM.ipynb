# %%
import pandas as pd

# %%
input_file = pd.read_csv('Bigset.csv')

# %%
input_file.head()
# Out:
#    Alphabets  Dash  DigLetRatio  Digits  Dollar  DomainLength  Dots  Eq_sym  \
# 0         77     2     0.324675      25       0             3     2       5
# 1         77     2     0.324675      25       0             3     2       5
# 2         77     2     0.324675      25       0             3     2       5
# 3         77     2     0.324675      25       0             3     2       5
# 4         77     2     0.324675      25       0             3     2       5
#
#    Labels  Len_of_URL  NonAlpha  Q_mark  Special_sym  Subdomains  \
# 0       0         122        45       1            8           0
# 1       0         122        45       1            8           0
# 2       0         122        45       1            8           0
# 3       0         122        45       1            8           0
# 4       0         122        45       1            8           0
#
#                                                  URL  Vow-Cons-Ratio  https
# 0  /account/general?FORM=SEFD&ru=http%3a%2f%2fwww...        0.414634      0
# 1  /account/general?FORM=SEFD&ru=http%3a%2f%2fwww...        0.450000      0
# 2  /account/general?FORM=SEFD&ru=http%3a%2f%2fwww...        0.450000      0
# 3  /account/general?FORM=SEFD&ru=http%3a%2f%2fwww...        0.414634      0
# 4  /account/general?FORM=SEFD&ru=http%3a%2f%2fwww...        0.414634      0

# %%
input_file.describe()
# Out:
#           Alphabets          Dash   DigLetRatio        Digits        Dollar  \
# count  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06
# mean   9.176825e+01  2.272867e+00  1.698144e-01  1.757204e+01  9.571446e-05
# std    7.204392e+01  2.582465e+00  2.136656e-01  4.189332e+01  3.434181e-02
# min    4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.900000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    6.500000e+01  2.000000e+00  1.363636e-01  1.400000e+01  0.000000e+00
# 75%    1.510000e+02  3.000000e+00  2.045455e-01  2.500000e+01  0.000000e+00
# max    4.087000e+03  9.000000e+01  7.229730e+00  1.726000e+03  4.100000e+01
#
#        DomainLength          Dots        Eq_sym        Labels    Len_of_URL  \
# count  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06
# mean   1.780985e+01  2.886854e+00  1.513664e+00  5.350855e-03  1.273332e+02
# std    3.851554e+00  2.007495e+00  1.864490e+00  7.295358e-02  1.178815e+02
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.100000e+01
# 25%    1.500000e+01  2.000000e+00  0.000000e+00  0.000000e+00  5.300000e+01
# 50%    1.900000e+01  2.000000e+00  1.000000e+00  0.000000e+00  9.200000e+01
# 75%    1.900000e+01  3.000000e+00  2.000000e+00  0.000000e+00  2.080000e+02
# max    2.320000e+02  7.800000e+01  5.700000e+01  1.000000e+00  1.638700e+04
#
#            NonAlpha        Q_mark   Special_sym    Subdomains  Vow-Cons-Ratio  \
# count  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06    3.604471e+06
# mean   3.557244e+01  5.685478e-01  6.222958e+00  3.536208e+00    4.123715e-01
# std    5.399627e+01  5.076895e-01  1.052874e+01  9.452892e+00    1.226724e-01
# min    2.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00
# 25%    1.100000e+01  0.000000e+00  1.000000e+00  3.000000e+00    3.181818e-01
# 50%    2.800000e+01  1.000000e+00  2.000000e+00  3.000000e+00    4.166667e-01
# 75%    5.000000e+01  1.000000e+00  9.000000e+00  5.000000e+00    5.000000e-01
# max    1.230100e+04  1.200000e+01  1.027000e+03  1.229000e+04    2.478261e+00
#
#               https
# count  3.604471e+06
# mean   7.504763e-01
# std    4.327374e-01
# min    0.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00

# %%
from sklearn import svm
import numpy

# %%
from sklearn.model_selection import train_test_split

# %%
model = svm.SVC(kernel='linear')

# %%
X=input_file.drop(['Labels','URL'],axis=1)

# %%
X.describe()
# Out:
#           Alphabets          Dash   DigLetRatio        Digits        Dollar  \
# count  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06
# mean   9.176825e+01  2.272867e+00  1.698144e-01  1.757204e+01  9.571446e-05
# std    7.204392e+01  2.582465e+00  2.136656e-01  4.189332e+01  3.434181e-02
# min    4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.900000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    6.500000e+01  2.000000e+00  1.363636e-01  1.400000e+01  0.000000e+00
# 75%    1.510000e+02  3.000000e+00  2.045455e-01  2.500000e+01  0.000000e+00
# max    4.087000e+03  9.000000e+01  7.229730e+00  1.726000e+03  4.100000e+01
#
#        DomainLength          Dots        Eq_sym    Len_of_URL      NonAlpha  \
# count  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06  3.604471e+06
# mean   1.780985e+01  2.886854e+00  1.513664e+00  1.273332e+02  3.557244e+01
# std    3.851554e+00  2.007495e+00  1.864490e+00  1.178815e+02  5.399627e+01
# min    1.000000e+00  0.000000e+00  0.000000e+00  1.100000e+01  2.000000e+00
# 25%    1.500000e+01  2.000000e+00  0.000000e+00  5.300000e+01  1.100000e+01
# 50%    1.900000e+01  2.000000e+00  1.000000e+00  9.200000e+01  2.800000e+01
# 75%    1.900000e+01  3.000000e+00  2.000000e+00  2.080000e+02  5.000000e+01
# max    2.320000e+02  7.800000e+01  5.700000e+01  1.638700e+04  1.230100e+04
#
#              Q_mark   Special_sym    Subdomains  Vow-Cons-Ratio         https
# count  3.604471e+06  3.604471e+06  3.604471e+06    3.604471e+06  3.604471e+06
# mean   5.685478e-01  6.222958e+00  3.536208e+00    4.123715e-01  7.504763e-01
# std    5.076895e-01  1.052874e+01  9.452892e+00    1.226724e-01  4.327374e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  1.000000e+00  3.000000e+00    3.181818e-01  1.000000e+00
# 50%    1.000000e+00  2.000000e+00  3.000000e+00    4.166667e-01  1.000000e+00
# 75%    1.000000e+00  9.000000e+00  5.000000e+00    5.000000e-01  1.000000e+00
# max    1.200000e+01  1.027000e+03  1.229000e+04    2.478261e+00  1.000000e+00

# %%
y=input_file.Labels

# %%
y.value_counts()
# Out:
# 0    3585184
# 1      19287
# Name: Labels, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.3, random_state = 100)

# %%
model.fit(X_train,y_train)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predictions)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(y_test,predictions)

# %%
print (classification_report(y_test,predictions))

# %%
import seaborn as sns
sns.pairplot(pairplot,hue = "Labels")
